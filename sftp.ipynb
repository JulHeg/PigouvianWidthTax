# %%
import pysftp

with pysftp.Connection('192.168.1.13', username='pi', password='raspberry') as sftp:
    test = sftp.get('car_silhouette.png')
    
# Show the image we just got
import matplotlib.pyplot as plt
file_path = 'car_silhouette.png'
test = plt.imread(file_path)
plt.imshow(test)
plt.show()

# %%
test
